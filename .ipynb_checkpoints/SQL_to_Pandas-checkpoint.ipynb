# %%
# Import SQLAlchemy `automap` and other dependencies here
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, inspect, func

# %%
# Create an engine for the postgresql database
engine = create_engine("postgresql://postgres:postgres@localhost/SQL_Homework_db", echo=False)
connection = engine.connect()

#download 'conda install -c anaconda psycopg2'

# %% [markdown]
# ## Explore Database

# %%
#required before query the engine
session = Session(bind=engine)

# %%
#Use automap_base
base = automap_base()
base.prepare(engine, reflect= True)

# %%
#to show table names
base.classes.keys()
# Out:
# ['dept', 'dept_emp', 'dept_mgr', 'employee', 'salary', 'titles']

# %%
inspector = inspect(engine)

# %%
#review columns
columns= inspector.get_columns('salary')
for c in columns:
    print(c['name'])
# Out:
# emp_no
# salary
# from_date
# to_date
# salary_id

# %% [markdown]
# ## Reflect database and Query

# %%
emp_salaries = engine.execute('SELECT employee.first_name, employee.last_name, employee.gender,salary.salary FROM employee JOIN salary on employee.emp_no = salary.emp_no;').fetchall()
# Out:
# [('Kyoichi', 'Maliniak', 'M', 78228),
#  ('Duangkaew', 'Piveteau', 'F', 72488),
#  ('Mary', 'Sluis', 'F', 42365),
#  ('Eberhardt', 'Terkki', 'M', 40000),
#  ('Cristinel', 'Bouloucos', 'F', 71380),
#  ('Alain', 'Chappelet', 'M', 41538),
#  ('Pradeep', 'Makrucki', 'M', 40000),
#  ('Moss', 'Shanbhogue', 'M', 41971),
#  ('Hidefumi', 'Caine', 'M', 48817),
#  ('Berhard', 'McFarlin', 'M', 52787),
#  ('Danel', 'Mondadori', 'F', 47280),
#  ('Kenroku', 'Malabarba', 'M', 40000),
#  ('Jayson', 'Mandell', 'M', 61395),
#  ('Kiyotoshi', 'Blokdijk', 'F', 52284),
#  ('Sumali', 'Fargier', 'M', 49879),
#  ('Duangkaew', 'Rassart', 'M', 56990),
#  ('Pragnesh', 'Iisaka', 'M', 48041),
#  ('Deniz', 'Duclos', 'F', 40000),
#  ('Genta', 'Kolvik', 'M', 40000),
#  ('Carrsten', 'Schmiedel', 'F', 62922),
#  ('Karoline', 'Cesareni', 'F', 79474),
#  ('Foong', 'Flasterstein', 'M', 56292),
#  ('Frederique', 'Tempesti', 'F', 58918),
#  ('Serap', 'Etalle', 'M', 50330),
#  ('Taizo', 'Oxman', 'F', 40000),
# ...

# %%
emp_salaries
# Out:
# []
